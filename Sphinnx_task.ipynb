# %% [markdown]
# <a href="https://colab.research.google.com/github/SAUMYA-01/ML-Projects/blob/main/Sphinnx_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install moviepy
# !pip install pyAudioAnalysis

# %%
import moviepy.editor as mp
# Define function to extract audio from video
def extract_audio(video_path, audio_output_path):
    video = mp.VideoFileClip(video_path)
    audio = video.audio
    audio.write_audiofile(audio_output_path)

# Path to the input video file
#video_path = "F:\Sphinx task\video input.mp4"
video_path = r"/content/sample_data/sample.mp4"


# Path to save the extracted audio file
audio_output_path = "/content/sample_data/audio.wav"

# Extract audio from video
extract_audio(video_path, audio_output_path)
# Out:
# MoviePy - Writing audio in /content/sample_data/audio.wav
# MoviePy - Done.

# %%
# !pip install speechrecognition

# %%
# !pip install googletrans==3.1.0a0
# !pip install speechrecognition

#from googletrans import Translator
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for googletrans: filename=googletrans-3.1.0a0-py3-none-any.whl size=16353 sha256=ec43b8caaa0bdf0406778433340a1a55caa2fbceed820ed7c3deb7a529a5d6d9
#   Stored in directory: /root/.cache/pip/wheels/50/5d/3c/8477d0af4ca2b8b1308812c09f1930863caeebc762fe265a95
# Successfully built googletrans
# ...
#   Attempting uninstall: googletrans
#     Found existing installation: googletrans 3.0.0
#     Uninstalling googletrans-3.0.0:
#       Successfully uninstalled googletrans-3.0.0
# ...

# %%
from googletrans import Translator
import speech_recognition as sr

# %%
# !pip install SpeechRecognition
# !pip install PyAudio
# !pip install gTTS
# Out:
# ...
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 3108, in _dep_map
#     return self.__dep_map
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 2901, in __getattr__
#     raise AttributeError(attr)
# AttributeError: _DistInfoDistribution__dep_map
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/base_command.py", line 169, in exc_logging_wrapper
#     status = run_func(*args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/req_command.py", line 242, in wrapper
#     return func(self, options, args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/commands/install.py", line 441, in run
#     conflicts = self._determine_conflicts(to_install)
# ...

# %%
# !pip install playsound==1.2.2

# %%
# !pip install pygobject
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.9/346.9 kB 3.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × Building wheel for pycairo (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for pycairo
# Failed to build pycairo
# ERROR: Could not build wheels for pycairo, which is required to install pyproject.toml-based projects

# %%
import googletrans
import speech_recognition
import gtts
from IPython.display import Audio
import os

audio_output_path = "/content/sample_data/audio.wav"

recognizer = speech_recognition.Recognizer()

# Load the audio file
with speech_recognition.AudioFile(audio_output_path) as source:
    audio_data = recognizer.record(source)

# Recognize the audio
text = recognizer.recognize_google(audio_data, language="en")
print("Recognized Text:", text)

# Translate the text
translator = googletrans.Translator()
translation = translator.translate(text, dest="hi")
print("Translated Text:", translation.text)

# Convert translated text to audio
converted_audio = gtts.gTTS(translation.text, lang="hi")
converted_audio_path = "hello.mp3"
converted_audio.save(converted_audio_path)

# Play the audio
Audio(converted_audio_path, autoplay=True)
# Out:
# Recognized Text: I was on the phone for an hour who were you talking to for an hour Sam an old friend from college when is the last time you talked to him at college graduation wow that was 30 years ago we had a lot of catching up to do
# Translated Text: मैं एक घंटे तक फोन पर था, आप एक घंटे तक किससे बात कर रहे थे, सैम, कॉलेज का पुराना दोस्त, आखिरी बार आपने कॉलेज ग्रेजुएशन के दौरान उससे कब बात की थी, वाह, वह 30 साल पहले था, हमें बहुत सारी बातें करनी थीं
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !pip install moviepy

# %%
from moviepy.editor import VideoFileClip, AudioFileClip

# Load the MP4 video
video_clip = VideoFileClip("/content/sample_data/sample.mp4")

# Load the converted audio
audio_clip = AudioFileClip("hello.mp3")

# Set the audio of the video to the converted audio
video_clip = video_clip.set_audio(audio_clip)

# Write the new video with the integrated audio
video_clip.write_videofile("output_video.mp4", codec="libx264", audio_codec="aac")
# Out:
# Moviepy - Building video output_video.mp4.
# MoviePy - Writing audio in output_videoTEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video output_video.mp4
# Moviepy - Done !
# Moviepy - video ready output_video.mp4
